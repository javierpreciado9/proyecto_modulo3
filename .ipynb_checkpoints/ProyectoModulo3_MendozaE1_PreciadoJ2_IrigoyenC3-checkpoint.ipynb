# %% [markdown]
# Considere un sistema ecológico simple compuesto solamente de dos especies: coyotes (y) y correcaminos (x), donde los primeros se alimentan de los segundos. Los tamaños de las poblaciones cambian de acuerdo con las ecuaciones:
#
#
#
#
# que se pueden entender de la siguiente manera: si no hay coyotes (y), los correcaminos se reproducen con una velocidad de crecimiento k1x; si no hay correcaminos, la especie de coyotes desaparece con velocidad k4y. El término xy representa la interacción entre las dos especies, y las constantes k2 y k3 dependen de la habilidad de los depredadores para atrapar a los correcaminos y de la habilidad de éstos para huir. Las poblaciones de los coyotes y los correcaminos cambian cíclicamente. Si se tiene que los valores son de k1=0.4, de k2=0.02, k3=0.001 y k4=0.3. Utilizando x (0) = 30 e y(0) = 3 como condiciones iniciales. Determina la cantidad de cada especie en t=2 .

# %% [markdown]
# ## Proyecto Modulo 3: Sistema Ecológico de dos especies
#
# ##### Integrantes:
# - Erick Mendoza
# - Javier Preciado
# - Carlos Irigoyen

# %% [markdown]
# ## Objetivos
#
# ### Generales:
# - Determinar la cantidad de especies (coyotes y correcaminos) en 5 años
#
# ### Específicos:
# - Desarrollar formula de tamaño de poblaciones.
# - Resolver numericamente la ecuación.
# - Graficar para comparación de resultados.

# %% [markdown]
# ### Modelo que representa el problema.

# %% [markdown]
# \begin{align}
# \frac{dx}{dt} &= k_1x-k_2xy\\
# \frac{dy}{dt} &= k_3xy-k_4y,
# \end{align}

# %% [markdown]
# ### Simulación 1
# - y = coyotes
# - x = correcaminos
#
# - $k_1$ = 0.4 velocidad de crecimiento de los correcaminos
# - $k_2$ = 0.02 habilidad de cazar de los coyotes
# - $k_3$ = 0.001 habilidad de huir de los correcaminos
# - $k_4$ = 0.3 velocidad de desaparición de los coyotes.
# - $t$ = 25 y años

# %%
# Importar librerías
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Importamos función para integración numérica
from scipy.integrate import odeint

# %%
k1=.4
k2=.02
k3=.001
k4=.3

# %%
def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# %%
# Primer condición inicial
x0 = np.array([30, 3])
# Vector de tiempo
t = np.linspace(0,25, 100)

# %%
# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# %%
# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# Al observar la gráfica, podemos intuir que la población de correcaminos es muchos mayor que a de los coyotes por el factor importante sobre la habilidad de los coyotes para cazar es de .001 (atrapan 1 de 1,000), por lo tanto a los 12 años, los correcaminos alcanzan su máxima población y después de 14 años, se comienzan a igualar el tamaño de población de las dos especies.

# %% [markdown]
# ### Simulación 2
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.006
# - $k_2$ = 0.02
# - $k_3$ = 0.001
# - $k_4$ = 0.3
# - $t$ = 25 años

# %%
k1=.006
k2=.02
k3=.001
k4=.3

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([30,3])
# Vector de tiempo
t = np.linspace(0, 25, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# Al observar la gráfica cambiamos nuestro $k_1$ = 0.0006, podemos intuir que la población de correcaminos va a estar oscilando entre 25-30 mientras que la población de coyotes va tendiendo a 0; la especie que se mantendrá viva sería la de los correcaminos ya que en esta simulación la velocidad de crecimiento de los correcaminos bajo un alto porcentaje.

# %% [markdown]
# ### Simulación 3
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.4
# - $k_2$ = 0.005
# - $k_3$ = 0.001
# - $k_4$ = 0.3
# - $t$ = 25 años

# %%
k1=.4
k2=.005
k3=.001
k4=.3

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([30,3])
# Vector de tiempo
t = np.linspace(0, 25, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# En ésta gráfica cambiamos la $k_2$ = 0.005, podemos observar que a los 12 años los correcaminos alcanzan su población máxima en 2,400 aproximadamente mientrás el la población máxima de coyotes es de 500, la habilidad para cazar de los coyotes fue muy baja.

# %% [markdown]
# ### Simulación 4
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.4
# - $k_2$ = 0.02
# - $k_3$ = 0.1
# - $k_4$ = 0.3
# - $t$ = 25 años

# %%
k1=.4
k2=.02
k3=.1
k4=.3

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([30,3])
# Vector de tiempo
t = np.linspace(0, 25, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# Con un $k_3$ = .1, en la gráfica podemos observar que los coyotes alcanzan su población máxima en 180 aproximadamente, ya que la habilidad de huir de los correcaminos fue baja.

# %% [markdown]
# ### Simulación 5
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.4
# - $k_2$ = 0.02
# - $k_3$ = 0.001
# - $k_4$ = 0.0005
# - $t$ = 25 años

# %%
k1=.4
k2=.02
k3=.001
k4=.0005

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([30,3])
# Vector de tiempo
t = np.linspace(0, 25, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# Con un $k_4$ = 0.0005 podemos observar que la población de los coyotes sigue disminuyendo y no tiene un máximo de población similar al de los correcaminos, esto es debido a que las habilidades de los correcaminos son más alta para huir que la del los coyotes para cazar. Aunque no es mucha la diferencia.

# %% [markdown]
# ### Simulación 6
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.04
# - $k_2$ = 0.008
# - $k_3$ = 0.001
# - $k_4$ = 0.011
# - $t$ = 200 años

# %%
k1=.04
k2=.008
k3=.001
k4=.011

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([50,5])
# Vector de tiempo
t = np.linspace(0, 200, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# En ésta gráfica hubo un cambio de datos en los años (t=200), y en las habilidades las dos especies, por lo tanto el futuro de las especie tiende a converger por el sistema ecológico que va nivelando el número de población, se puede ver que por más correcaminos que sean, sus habilidades para huir/cazar son bastante competitivas, hasta ahora es la gráfica con mayor acercamiento a la realidad.

# %% [markdown]
# ### Simulación 7
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.4
# - $k_2$ = 0.02
# - $k_3$ = 0.001
# - $k_4$ = 0.3
# - $t$ = 200 años

# %%
k1=.4
k2=.02
k3=.001
k4=.3

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([50,5])
# Vector de tiempo
t = np.linspace(0, 200, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# Para saber que pasó en esta gráfica podemos observar que el tiempo en 200 años, funciona de manera cíclica con las habilidades origniales del problema, las dos especies tienen puntos máximos y mínimos de población, van a sobrevivir en 200 años.

# %% [markdown]
# ### Simulación 8
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.1
# - $k_2$ = 0.1
# - $k_3$ = 0.01
# - $k_4$ = 0.3
# - $t$ = 200 años

# %%
k1=.4
k2=.03
k3=.01
k4=.1

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([50,5])
# Vector de tiempo
t = np.linspace(0, 200, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# El tiempo se mantiene en 200, pero las habilidades de las especies han cambiado, como podemos observar los coyotes han mejorado bastante y su poblacición ha crecido de tal manera que por poco alcanza a la de los correcaminos, es importante resaltar que es una función cíclica como funciona en la realidad, sin que hubiese intervención del ser humano.

# %% [markdown]
# ### Simulación 9
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0.4
# - $k_2$ = 0.02
# - $k_3$ = 0.001
# - $k_4$ = 0.3
# - $t$ = 200 años

# %%
k1=.4
k2=.02
k3=.001
k4=.3

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([5,50])
# Vector de tiempo
t = np.linspace(0, 200, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# En ésta gráfica los datos que cambiaron fueron los de poblacición inicial y(0)= 50 coyotes, e x(0) = 5 correcaminos, se vuelve a dar un fenómeno cíclico aproximadamente aunque la poblaciçon de coyotes sea mucho mayor, su habilidad de cazar sigue siendo mala, y la habilidad de huir de los correcaminos supera por muy alto a su próxima extinción.

# %% [markdown]
# ### Simulación 10
#
# - y = coyotes
# - x = correcaminos
# - $k_1$ = 0
# - $k_2$ = 0
# - $k_3$ = 0
# - $k_4$ = 0
# - $t$ = 200 años

# %%
k1=0.0001
k2=0.0001
k3=0.0001
k4=0.0001

def Sist_eco(z, t):
    x = z[0]
    y = z[1]
    dx = k1*x-k2*x*y
    dy = k3*x*y-k4*y
    return np.array([dx, dy])

# Primer condición inicial
x0 = np.array([10,10])
# Vector de tiempo
t = np.linspace(0, 200, 100)

# Resolver numéricamente
xx = odeint(Sist_eco, x0, t)
# Separamos soluciones
x = xx[:, 0]
y = xx[:, 1]

# Gráficas de x1 vs. t y x2 vs. t
plt.figure(figsize=(8,6))
plt.plot(t, x, label='Población de correcaminos $x(t)$')
plt.plot(t, y, label='Población de coyotes $y(t)$')
plt.xlabel('Tiempo $t$')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretación
#
# En la última gráfica se puede observar que con los datos modificados, siendo la misma población incial de coyotes y correcaminos, con habilidades muy bajas e iguales, la especie que tiene a sobrevivir en 200 años sería la de los coyotes, ésta vez la habilidad mínima e igualitaria está a favor de los coyotes.
